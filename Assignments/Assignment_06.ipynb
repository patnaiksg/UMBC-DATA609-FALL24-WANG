# %% [markdown]
# <a href="https://colab.research.google.com/github/patnaiksg/UMBC_DATA690_FALL2024/blob/main/Assignments/Assignment_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Session 05

# %%
import pandas as pd
import plotly.express as px

pd.set_option("display.max_rows", None)

df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")

df.shape
# Out:
# (4123, 9)

# %%
df.sample(5)
# Out:
#       Year                   Country  GDP per capita (current US$)  \
# 807   2013                  Colombia                   8263.641929
# 1656  2007                   Hungary                  13940.909276
# 775   2019                     Chile                  14632.690308
# 2784  2014  Northern Mariana Islands                  16044.430731
# 2264  2007                    Malawi                    478.028076
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 807                                  75.82700         46237930.0          COL
# 1656                                 73.15122         10055780.0          HUN
# 775                                  80.32600         19039485.0          CHL
# 2784                                      NaN            51856.0          MNP
# 2264                                 53.94600         13495463.0          MWI
#
#                           Region         Income Group    Lending Type
# 807   Latin America & Caribbean   Upper middle income            IBRD
# 1656       Europe & Central Asia          High income  Not classified
# 775   Latin America & Caribbean           High income            IBRD
# 2784         East Asia & Pacific          High income  Not classified
# 2264         Sub-Saharan Africa            Low income             IDA

# %%
df.isna().sum()
# Out:
# Year                                         0
# Country                                      0
# GDP per capita (current US$)               161
# Life expectancy at birth, total (years)    346
# Population, total                            0
# Country Code                                 0
# Region                                       0
# Income Group                                 0
# Lending Type                                 0
# dtype: int64

# %%
df[["Year", "Country","GDP per capita (current US$)", "Life expectancy at birth, total (years)"]].sample(5)
# Out:
#       Year     Country  GDP per capita (current US$)  \
# 1256  2006        Fiji                   3483.597185
# 430   2016      Bhutan                   2879.546564
# 3627  2021  Tajikistan                    916.691967
# 1391  2008     Germany                  45612.710622
# 1715  2009   Indonesia                   2239.095265
#
#       Life expectancy at birth, total (years)
# 1256                                66.855000
# 430                                 70.602000
# 3627                                71.594000
# 1391                                79.736585
# 1715                                68.494000

# %%
df_2022 = df[df["Year"] != 2022]
df_2022.shape
# Out:
# (3906, 9)

# %%
df_2022.isna().sum()
# Out:
# Year                                         0
# Country                                      0
# GDP per capita (current US$)               140
# Life expectancy at birth, total (years)    129
# Population, total                            0
# Country Code                                 0
# Region                                       0
# Income Group                                 0
# Lending Type                                 0
# dtype: int64

# %%
df_2022 = df_2022.dropna()
df_2022.isna().sum()
# Out:
# Year                                       0
# Country                                    0
# GDP per capita (current US$)               0
# Life expectancy at birth, total (years)    0
# Population, total                          0
# Country Code                               0
# Region                                     0
# Income Group                               0
# Lending Type                               0
# dtype: int64

# %%
df_2022.shape
# Out:
# (3641, 9)

# %% [markdown]
# ## Homework Question 1:
#
# to check if this dataset has duplicate rows. If it has, only keep one from the duplicated rows and drop the rest.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Year, Country, GDP per capita (current US$), Life expectancy at birth, total (years), Population, total, Country Code, Region, Income Group, Lending Type]
# Index: []

# %%
df_cleaned = df.drop_duplicates()

print(f"Cleaned shape: {df_cleaned.shape}")
print(df_cleaned.sample(5))
# Out:
# Cleaned shape: (4123, 9)
#       Year                   Country  GDP per capita (current US$)  \
# 363   2006                    Belize                   5486.831434
# 2378  2007                Mauritania                   1378.215104
# 3300  2017           Slovak Republic                  17585.197002
# 3807  2011  Turks and Caicos Islands                  23649.714434
# 1956  2022                  Kiribati                   1701.970665
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 363                                 70.093000           288729.0          BLZ
# 2378                                62.228000          3153508.0          MRT
# 3300                                77.165854          5439232.0          SVK
# 3807                                76.195000            30816.0          TCA
# 1956                                      NaN           131232.0          KIR
#
#                           Region         Income Group    Lending Type
# 363   Latin America & Caribbean   Upper middle income            IBRD
# 2378         Sub-Saharan Africa   Lower middle income             IDA
# 3300       Europe & Central Asia          High income  Not classified
# 3807  Latin America & Caribbean           High income  Not classified
# 1956         East Asia & Pacific  Lower middle income             IDA

# %% [markdown]
# ## HW Question 2
#
# Find out if there is a relationship between wealth and health
#
# Pick any year worth of data and use plotly express to generate a scatter plot with GDP as x and life expectancy as y.

# %%
year_of_interest = 2019

df_2019 = df[df["Year"] == year_of_interest]
print(df_2019.shape)
df_2019.sample(5)
# Out:
# (217, 9)
#       Year       Country  GDP per capita (current US$)  \
# 3245  2019  Sierra Leone                    506.606914
# 813   2019      Colombia                   6436.509215
# 148   2019     Argentina                   9963.674162
# 2219  2019    Luxembourg                 112726.439673
# 243   2019    Azerbaijan                   4805.753718
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 3245                                60.255000          8046828.0          SLE
# 813                                 76.752000         50187406.0          COL
# 148                                 77.284000         44938712.0          ARG
# 2219                                82.639024           620001.0          LUX
# 243                                 73.102000         10024283.0          AZE
#
#                           Region         Income Group    Lending Type
# 3245         Sub-Saharan Africa            Low income             IDA
# 813   Latin America & Caribbean   Upper middle income            IBRD
# 148   Latin America & Caribbean   Upper middle income            IBRD
# 2219       Europe & Central Asia          High income  Not classified
# 243        Europe & Central Asia  Upper middle income            IBRD

# %%
df_2019.isna().sum()
# Out:
# Year                                       0
# Country                                    0
# GDP per capita (current US$)               6
# Life expectancy at birth, total (years)    8
# Population, total                          0
# Country Code                               0
# Region                                     0
# Income Group                               0
# Lending Type                               0
# dtype: int64

# %%
df_2019 = df_2019.dropna(subset=["GDP per capita (current US$)", "Life expectancy at birth, total (years)"])
print(df_2019.shape)
df_2019.sample(5)
# Out:
# (203, 9)
#       Year                 Country  GDP per capita (current US$)  \
# 908   2019           Cote d'Ivoire                   2290.787379
# 3625  2019              Tajikistan                    889.023372
# 452   2019                 Bolivia                   3472.380831
# 471   2019  Bosnia and Herzegovina                   6094.724823
# 3093  2019                  Rwanda                    806.100820
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 908                                    59.319         26147551.0          CIV
# 3625                                   70.867          9337003.0          TJK
# 452                                    67.841         11777315.0          BOL
# 471                                    77.241          3360711.0          BIH
# 3093                                   66.437         12835028.0          RWA
#
#                           Region         Income Group Lending Type
# 908          Sub-Saharan Africa   Lower middle income          IDA
# 3625       Europe & Central Asia  Lower middle income          IDA
# 452   Latin America & Caribbean   Lower middle income         IBRD
# 471        Europe & Central Asia  Upper middle income         IBRD
# 3093         Sub-Saharan Africa            Low income          IDA

# %%
fig = px.scatter(
    df_2019,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    color="Country",
    size="Population, total",
    title=f"Relationship between GDP per Capita and Life Expectancy in {year_of_interest}",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    },
    height=600
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cd42a87f-1114-4c47-a69d-1d36723c7f41" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd42a87f-1114-4c47-a69d-1d36723c7f41")) {                    Plotly.newPlot(                        "cd42a87f-1114-4c47-a69d-1d36723c7f41",                        [{"hovertemplate":"Country=Afghanistan\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afghanistan","marker":{"color":"#636efa","size":[37769499.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Afghanistan","orientation":"v","showlegend":true,"x":[497.741429257502],"xaxis":"x","y":[63.565],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Albania\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Albania","marker":{"color":"#EF553B","size":[2854191.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Albania","orientation":"v","showlegend":true,"x":[5396.2142432843],"xaxis":"x","y":[79.282],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Algeria\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Algeria","marker":{"color":"#00cc96","size":[42705368.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Algeria","orientation":"v","showlegend":true,"x":[4021.9832660524],"xaxis":"x","y":[76.474],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Angola\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Angola","marker":{"color":"#ab63fa","size":[32353588.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Angola","orientation":"v","showlegend":true,"x":[2191.34776373555],"xaxis":"x","y":[62.448],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Antigua and Barbuda\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Antigua and Barbuda","marker":{"color":"#FFA15A","size":[92117.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Antigua and Barbuda","orientation":"v","showlegend":true,"x":[18730.0047966374],"xaxis":"x","y":[78.691],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Argentina\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Argentina","marker":{"color":"#19d3f3","size":[44938712.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Argentina","orientation":"v","showlegend":true,"x":[9963.67416171662],"xaxis":"x","y":[77.284],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Armenia\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Armenia","marker":{"color":"#FF6692","size":[2820602.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Armenia","orientation":"v","showlegend":true,"x":[4828.50488626598],"xaxis":"x","y":[75.439],"yaxis":"y"," ...

# %% [markdown]
# ## Compare China, US, India, Russia

# %%
df_4_countries = df_2019[df_2019["Country Code"].isin(["USA", "CHN", "IND", "RUS"])]
print(df_4_countries.shape)
df_4_countries
# Out:
# (4, 9)
#       Year             Country  GDP per capita (current US$)  \
# 794   2019               China                  10143.860221
# 1706  2019               India                   2050.163800
# 3074  2019  Russian Federation                  11536.258789
# 3929  2019       United States                  65120.394663
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 794                                 77.968000       1.407745e+09          CHN
# 1706                                70.910000       1.383112e+09          IND
# 3074                                73.083902       1.444063e+08          RUS
# 3929                                78.787805       3.283300e+08          USA
#
#                      Region         Income Group    Lending Type
# 794     East Asia & Pacific  Upper middle income            IBRD
# 1706             South Asia  Lower middle income            IBRD
# 3074  Europe & Central Asia  Upper middle income            IBRD
# 3929          North America          High income  Not classified

# %%
fig = px.scatter(
    df_4_countries,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    color="Country",
    text="Country",
    size="Population, total",
    title=f"Compare Wealth and Health of Four Major World Powers {year_of_interest}",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    },
    height=600,
    width=1000
)

# Update text position
fig.update_traces(textposition='top center')
fig.update_layout(showlegend=False)
# Add an annotation
fig.add_annotation(
    x=55000,  # X coordinate
    y=71,     # Y coordinate
    text="Note: The size of the dot represents the population.",  # Annotation text
    showarrow=False  # Do not show arrow
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="72eff7dc-6627-4e0c-9b6a-a92d33f02fb1" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72eff7dc-6627-4e0c-9b6a-a92d33f02fb1")) {                    Plotly.newPlot(                        "72eff7dc-6627-4e0c-9b6a-a92d33f02fb1",                        [{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","marker":{"color":"#636efa","size":[1407745000.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"China","orientation":"v","showlegend":true,"text":["China"],"x":[10143.8602205959],"xaxis":"x","y":[77.968],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"India","marker":{"color":"#EF553B","size":[1383112050.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"India","orientation":"v","showlegend":true,"text":["India"],"x":[2050.1638002619],"xaxis":"x","y":[70.91],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Russian Federation","marker":{"color":"#00cc96","size":[144406261.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"Russian Federation","orientation":"v","showlegend":true,"text":["Russian Federation"],"x":[11536.2587890625],"xaxis":"x","y":[73.0839024390244],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","marker":{"color":"#ab63fa","size":[328329953.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"United States","orientation":"v","showlegend":true,"text":["United States"],"x":[65120.3946628653],"xaxis":"x","y":[78.7878048780488],"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888 ...

# %%
df_quad = df[df["Country Code"].isin(["USA", "CHN", "IND", "RUS"])]
print(df_quad.shape)
df_quad.sample(5)
# Out:
# (76, 9)
#       Year             Country  GDP per capita (current US$)  \
# 1693  2006               India                    802.013742
# 3064  2009  Russian Federation                   8562.824219
# 1701  2014               India                   1559.863779
# 3076  2021  Russian Federation                  12532.050781
# 3074  2019  Russian Federation                  11536.258789
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 1693                                65.412000       1.172374e+09          IND
# 3064                                68.684634       1.427853e+08          RUS
# 1701                                69.074000       1.307247e+09          IND
# 3076                                69.361220       1.441305e+08          RUS
# 3074                                73.083902       1.444063e+08          RUS
#
#                      Region         Income Group Lending Type
# 1693             South Asia  Lower middle income         IBRD
# 3064  Europe & Central Asia  Upper middle income         IBRD
# 1701             South Asia  Lower middle income         IBRD
# 3076  Europe & Central Asia  Upper middle income         IBRD
# 3074  Europe & Central Asia  Upper middle income         IBRD

# %%
fig = px.line(
    df_quad,
    x="Year",
    color="Country",
    y="GDP per capita (current US$)",
    text="Country"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7df5542a-42c9-4219-a89e-03f88f2834e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7df5542a-42c9-4219-a89e-03f88f2834e9")) {                    Plotly.newPlot(                        "7df5542a-42c9-4219-a89e-03f88f2834e9",                        [{"hovertemplate":"Country=%{text}\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"China","orientation":"v","showlegend":true,"text":["China","China","China","China","China","China","China","China","China","China","China","China","China","China","China","China","China","China","China"],"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[1508.66791563578,1753.41419162417,2099.2194300786,2693.95873162278,3468.32706308591,3832.22745696438,4550.47394361131,5614.3860223103,6300.58217952904,7020.38607424065,7636.0743401587,8016.44559491162,8094.39016730811,8817.04560829162,9905.40638307759,10143.8602205959,10408.7195541075,12617.5051041181,12720.2163182363],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{text}\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"India","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"India","orientation":"v","showlegend":true,"text":["India","India","India","India","India","India","India","India","India","India","India","India","India","India","India","India","India","India","India"],"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[624.105094381691,710.509344848758,802.013742049265,1022.73246704551,993.503405266506,1096.63613605519,1350.63447029491,1449.60330101563,1434.01798721629,1438.05700508042,1559.86377870535,1590.17433135955,1714.27953740039,1957.96981329558,1974.3777314935,2050.1638002619,1913.21973278751,2238.12714218765,2410.88802070689],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{text}\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Russian Federation","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"Russian Federation","orientation":"v","showlegend":true,"text":["Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation"],"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[4102.36474609375,5323.455078125,6920.19970703125,9101.2392578125,11635.2841796875,8562.82421875,10674.990234375,14311.064453125,15420.859375,15974.6220703125,14095.646484375,9313.021484375,8704.89453125,10720.33203125,11287.3544921875,11536.2587890625,10194.44140625,12532.05078125,15270.7060546875],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{text}\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"United States","orientation":"v","showlegend":true,"text":[" ...

# %% [markdown]
# ## 10/9/20204 Homework Question 1:
#
# for the Quad time series comparison chart above, try to add country name to the end of the line and then remove the color legend.

# %%
fig = px.line(
    df_quad,
    x="Year",
    color="Country",
    y="GDP per capita (current US$)",
    text="Country"
)

fig.update_traces(textposition='top right')
fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f7872484-7945-41a0-8c9d-3099b4a9b84c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7872484-7945-41a0-8c9d-3099b4a9b84c")) {                    Plotly.newPlot(                        "f7872484-7945-41a0-8c9d-3099b4a9b84c",                        [{"hovertemplate":"Country=%{text}\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"China","orientation":"v","showlegend":true,"text":["China","China","China","China","China","China","China","China","China","China","China","China","China","China","China","China","China","China","China"],"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[1508.66791563578,1753.41419162417,2099.2194300786,2693.95873162278,3468.32706308591,3832.22745696438,4550.47394361131,5614.3860223103,6300.58217952904,7020.38607424065,7636.0743401587,8016.44559491162,8094.39016730811,8817.04560829162,9905.40638307759,10143.8602205959,10408.7195541075,12617.5051041181,12720.2163182363],"yaxis":"y","type":"scatter","textposition":"top right"},{"hovertemplate":"Country=%{text}\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"India","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"India","orientation":"v","showlegend":true,"text":["India","India","India","India","India","India","India","India","India","India","India","India","India","India","India","India","India","India","India"],"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[624.105094381691,710.509344848758,802.013742049265,1022.73246704551,993.503405266506,1096.63613605519,1350.63447029491,1449.60330101563,1434.01798721629,1438.05700508042,1559.86377870535,1590.17433135955,1714.27953740039,1957.96981329558,1974.3777314935,2050.1638002619,1913.21973278751,2238.12714218765,2410.88802070689],"yaxis":"y","type":"scatter","textposition":"top right"},{"hovertemplate":"Country=%{text}\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Russian Federation","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"Russian Federation","orientation":"v","showlegend":true,"text":["Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation"],"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[4102.36474609375,5323.455078125,6920.19970703125,9101.2392578125,11635.2841796875,8562.82421875,10674.990234375,14311.064453125,15420.859375,15974.6220703125,14095.646484375,9313.021484375,8704.89453125,10720.33203125,11287.3544921875,11536.2587890625,10194.44140625,12532.05078125,15270.7060546875],"yaxis":"y","type":"scatter","textposition":"top right"},{"hovertemplate":"Country=%{text}\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+m ...

# %%
df_group = df.groupby(["Year", "Region"])["Population, total"].sum().reset_index()
df_group.sample(5)
# Out:
#     Year                      Region  Population, total
# 73  2014  Middle East & North Africa       4.316646e+08
# 9   2005  Latin America & Caribbean        5.567395e+08
# 20  2006         Sub-Saharan Africa        7.881100e+08
# 63  2013         East Asia & Pacific       2.237930e+09
# 75  2014                  South Asia       1.754030e+09

# %% [markdown]
# Home work #5
# Pick a few countries of your interest (for example, G7, BRICS, Nordic countries).
# - 1 Create a line chart showing the trend of Life Expectancy over time for comparing those countries.
# - 2 Pick a year from the data of the above few countries and create a scatter plot to compare their GDP per capita and life expectancy. The size of the dots represent the population. This type of scatter plot is called bubble chart.
# - 3 Bonus - compute the average GDP per capita, the average life expectancy, and the total population for each year of all the seven regions (aggregation) and repeat 1 and 2 using the aggregated data for all regions

# %% [markdown]
# ## Question 1:

# %%
import random

# Select 10 random countries
random_countries = random.sample(list(df["Country"].unique()), 10)

# Filter the DataFrame to include only the selected countries
df_random_countries = df[df["Country"].isin(random_countries)]

# Create a line chart showing the trend of Life Expectancy over time
fig = px.line(
    df_random_countries,
    x="Year",
    y="Life expectancy at birth, total (years)",
    color="Country",
    title="Life Expectancy Trend for 10 Random Countries",
    labels={
        "Year": "Year",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    }
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="368c3bb0-ade3-4e54-aaa2-ab5b1072e43a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("368c3bb0-ade3-4e54-aaa2-ab5b1072e43a")) {                    Plotly.newPlot(                        "368c3bb0-ade3-4e54-aaa2-ab5b1072e43a",                        [{"hovertemplate":"Country=Afghanistan\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afghanistan","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Afghanistan","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[57.944,58.361,58.684,59.111,59.852,60.364,60.851,61.419,61.923,62.417,62.545,62.659,63.136,63.016,63.081,63.565,62.575,61.982,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Antigua and Barbuda\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Antigua and Barbuda","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Antigua and Barbuda","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[75.672,75.825,75.765,76.131,76.41,76.669,76.82,77.104,77.35,77.583,77.858,77.913,78.152,78.268,78.511,78.691,78.841,78.497,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Bahrain\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bahrain","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bahrain","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[76.56,76.931,77.156,77.634,78.084,78.461,78.748,78.89,79.081,79.246,79.328,79.405,79.557,79.689,79.857,80.019,79.174,78.76,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Belgium\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Belgium","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Belgium","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[78.8780487804878,78.9804878048781,79.380487804878,79.7829268292683,79.6804878048781,80.0341463414634,80.1829268292683,80.5853658536585,80.3853658536585,80.5878048780488,81.2878048780488,80.9926829268293,81.4390243902439,81.4926829268293,81.5951219512195,81.9951219512195,80.6951219512195,81.890243902439,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Bhutan\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bhutan","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bhutan","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[65.268,65.805,66.362,66.954,67.499,67.897,68.43,68.881,69.326,69.707,70.049,70.343,70.602,70.847,71.129,71.391,71.609,71.815,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Dominican Republic\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Dominican Republic","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Dominican Republic","orie ...

# %% [markdown]
# ## Question 2

# %%
year_of_interest = 2019

df_random_countries_year = df_random_countries[df_random_countries["Year"] == year_of_interest]

df_random_countries_year = df_random_countries_year.dropna(subset=["GDP per capita (current US$)", "Life expectancy at birth, total (years)"])

fig = px.scatter(
    df_random_countries_year,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    color="Country",
    text="Country",
    size="Population, total",
    title=f"GDP per Capita vs. Life Expectancy for 10 Random Countries in {year_of_interest}",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    }
)

fig.update_traces(textposition='top center')
fig.update_layout(showlegend=False)
# Add an annotation
fig.add_annotation(
    x=70000,  # X coordinate
    y=60,     # Y coordinate
    text="Note: The size of the dot represents the population.",  # Annotation text
    showarrow=False  # Do not show arrow
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bd8795fa-d20d-4d58-9aa8-33cc6a074b00" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd8795fa-d20d-4d58-9aa8-33cc6a074b00")) {                    Plotly.newPlot(                        "bd8795fa-d20d-4d58-9aa8-33cc6a074b00",                        [{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afghanistan","marker":{"color":"#636efa","size":[37769499.0],"sizemode":"area","sizeref":285301.485,"symbol":"circle"},"mode":"markers+text","name":"Afghanistan","orientation":"v","showlegend":true,"text":["Afghanistan"],"x":[497.741429257502],"xaxis":"x","y":[63.565],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Antigua and Barbuda","marker":{"color":"#EF553B","size":[92117.0],"sizemode":"area","sizeref":285301.485,"symbol":"circle"},"mode":"markers+text","name":"Antigua and Barbuda","orientation":"v","showlegend":true,"text":["Antigua and Barbuda"],"x":[18730.0047966374],"xaxis":"x","y":[78.691],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bahrain","marker":{"color":"#00cc96","size":[1494188.0],"sizemode":"area","sizeref":285301.485,"symbol":"circle"},"mode":"markers+text","name":"Bahrain","orientation":"v","showlegend":true,"text":["Bahrain"],"x":[25869.1129129041],"xaxis":"x","y":[80.019],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Belgium","marker":{"color":"#ab63fa","size":[11488980.0],"sizemode":"area","sizeref":285301.485,"symbol":"circle"},"mode":"markers+text","name":"Belgium","orientation":"v","showlegend":true,"text":["Belgium"],"x":[46641.7214017087],"xaxis":"x","y":[81.9951219512195],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bhutan","marker":{"color":"#FFA15A","size":[767459.0],"sizemode":"area","sizeref":285301.485,"symbol":"circle"},"mode":"markers+text","name":"Bhutan","orientation":"v","showlegend":true,"text":["Bhutan"],"x":[3564.59877168289],"xaxis":"x","y":[71.391],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Dominican Republic","marker":{"color":"#19d3f3","size":[10881882.0],"sizemode":"area","sizeref":285301.485,"symbol":"circle"},"mode":"markers+text","name":"Dominican Republic","orientation":"v","showlegend":true,"text":["Dominican Republic"],"x":[8173.34469885261],"xaxis":"x","y":[73.577],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Yea ...

# %% [markdown]
# ## Question 3 : Bonus

# %%
# Group by Year and Region, calculate average GDP per capita, average life expectancy, and total population
df_region_agg = df.groupby(["Year", "Region"]).agg(
    {
        "GDP per capita (current US$)": "mean",
        "Life expectancy at birth, total (years)": "mean",
        "Population, total": "sum"
    }
).reset_index()

df_region_agg.sample(5)
# Out:
#      Year                      Region  GDP per capita (current US$)  \
# 42   2010         East Asia & Pacific                  14068.845158
# 123  2021               North America                  78117.587729
# 89   2016                  South Asia                   2867.732464
# 30   2008  Latin America & Caribbean                   12585.765192
# 98   2018         East Asia & Pacific                  18083.532845
#
#      Life expectancy at birth, total (years)  Population, total
# 42                                 72.195699       2.187065e+09
# 123                                79.401959       3.703218e+08
# 89                                 70.600500       1.797073e+09
# 30                                 73.372907       5.763862e+08
# 98                                 73.848374       2.317809e+09

# %%
# Create a line chart showing the trend of Life Expectancy over time for all regions
fig = px.line(
    df_region_agg,
    x="Year",
    y="Life expectancy at birth, total (years)",
    color="Region",
    title="Life Expectancy Trend for All Regions",
    labels={
        "Year": "Year",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    }
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9dff31ea-5823-4c5b-8ec7-93c6f24a0185" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9dff31ea-5823-4c5b-8ec7-93c6f24a0185")) {                    Plotly.newPlot(                        "9dff31ea-5823-4c5b-8ec7-93c6f24a0185",                        [{"hovertemplate":"Region=East Asia & Pacific\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"East Asia & Pacific","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[70.82474605451937,71.03525226480836,71.35182855093257,71.53284791965567,71.55289167862267,71.93134289813486,72.1956987087518,72.4136262553802,72.63352725968436,72.85580703012913,73.06722883787661,73.2169756097561,73.38525538020087,73.59137517934003,73.8483737446198,74.0432230989957,74.14365566714491,73.64341893830704,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Europe & Central Asia\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Europe & Central Asia","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[74.8951915742794,74.99792727272728,75.27233303769401,75.49948070953438,75.9008713968958,76.20778137472284,76.45108115299335,76.83067450110866,77.04216097560976,77.25882793791575,77.56068115299334,77.53420044345899,77.83207627494457,77.99858669623062,78.13177738359202,78.39830288248336,77.36474589800444,77.08593215077606,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Latin America & Caribbean \u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean ","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Latin America & Caribbean ","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[72.3771243307555,72.71504045211184,72.99729625223081,73.12531290898275,73.37290660321237,73.64340809042237,73.50570969660916,73.93912790005949,74.13676740035693,74.24663176680548,74.42811957168352,74.51728494943485,74.63538548483046,74.5883503866746,74.79783780487804,74.75240731707316,73.94311280487804,72.96878231707316,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Middle East & North Africa\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Middle East & North Africa","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Middle East & North Africa","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[72.37166666666667,72.64277235772359,72.80688966318235,73.09993147502904,73.40060975609757,73.75654006968641,74.1584761904762,74.24478281068525,74.24767711962834,74.37635423925667,74.45095238095239,74.7327038327526,74.97042740998839,75.34821718931474,75.54567711962834,75.72125783972126,74.67093147502904,74.36790360046457,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=North America\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fext ...

# %%
# Pick a year from the data and create a scatter plot to compare their GDP per capita and life expectancy.
year_of_interest = 2019
df_region_agg_year = df_region_agg[df_region_agg["Year"] == year_of_interest]

fig = px.scatter(
    df_region_agg_year,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    color="Region",
    size="Population, total",
    title=f"GDP per Capita vs. Life Expectancy for All Regions in {year_of_interest}",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    }
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="63dfd623-847c-4f6b-8bb3-5449053c7415" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63dfd623-847c-4f6b-8bb3-5449053c7415")) {                    Plotly.newPlot(                        "63dfd623-847c-4f6b-8bb3-5449053c7415",                        [{"hovertemplate":"Region=East Asia & Pacific\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","marker":{"color":"#636efa","size":[2330265835.0],"sizemode":"area","sizeref":5825664.5875,"symbol":"circle"},"mode":"markers","name":"East Asia & Pacific","orientation":"v","showlegend":true,"x":[17906.003161543427],"xaxis":"x","y":[74.0432230989957],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Europe & Central Asia\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","size":[920277481.0],"sizemode":"area","sizeref":5825664.5875,"symbol":"circle"},"mode":"markers","name":"Europe & Central Asia","orientation":"v","showlegend":true,"x":[35566.32252548241],"xaxis":"x","y":[78.39830288248336],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Latin America & Caribbean \u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean ","marker":{"color":"#00cc96","size":[645295804.0],"sizemode":"area","sizeref":5825664.5875,"symbol":"circle"},"mode":"markers","name":"Latin America & Caribbean ","orientation":"v","showlegend":true,"x":[15465.703305292674],"xaxis":"x","y":[74.75240731707316],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Middle East & North Africa\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Middle East & North Africa","marker":{"color":"#ab63fa","size":[473201775.0],"sizemode":"area","sizeref":5825664.5875,"symbol":"circle"},"mode":"markers","name":"Middle East & North Africa","orientation":"v","showlegend":true,"x":[16111.826427618016],"xaxis":"x","y":[75.72125783972126],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=North America\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","marker":{"color":"#FFA15A","size":[365995094.0],"sizemode":"area","sizeref":5825664.5875,"symbol":"circle"},"mode":"markers","name":"North America","orientation":"v","showlegend":true,"x":[75882.5711787408],"xaxis":"x","y":[80.68319512195124],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=South Asia\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South Asia","marker":{"color":"#19d3f3","size":[1861598514.0],"sizemode":"area","sizeref":5825664.5875,"symbol":"circle"},"mode":"markers","name":"South Asia","orientation":"v","showlegend":true,"x":[3286.247982757694],"xaxis":"x","y":[71.38875],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Sub-Saharan Africa \u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fext ...

# %% [markdown]
# ## Homework Question 3
#
# Select a year of data. calculate total population of each region and make a pie chart to display the distribution of total population of all regions.

# %%
print(df.shape)
df.sample(10)
# Out:
# (4123, 9)
#       Year          Country  GDP per capita (current US$)  \
# 2207  2007       Luxembourg                 107475.320298
# 590   2005          Burundi                    151.188541
# 3247  2021     Sierra Leone                    504.621288
# 310   2010         Barbados                  16494.243041
# 3621  2015       Tajikistan                    970.362600
# 2196  2015        Lithuania                  14263.964577
# 2039  2010  Kyrgyz Republic                    880.038522
# 1234  2022         Ethiopia                   1027.585911
# 381   2005            Benin                    805.904685
# 4108  2008         Zimbabwe                    351.839101
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 2207                                79.382927           479993.0          LUX
# 590                                 53.023000          7388874.0          BDI
# 3247                                60.062000          8420641.0          SLE
# 310                                 75.712000           274711.0          BRB
# 3621                                69.306000          8524063.0          TJK
# 2196                                74.321951          2904910.0          LTU
# 2039                                69.300000          5447900.0          KGZ
# 1234                                      NaN        123379924.0          ETH
# 381                                 57.125000          8149419.0          BEN
# 4108                                46.723000         12550347.0          ZWE
#
#                           Region         Income Group    Lending Type
# 2207       Europe & Central Asia          High income  Not classified
# 590          Sub-Saharan Africa            Low income             IDA
# 3247         Sub-Saharan Africa            Low income             IDA
# 310   Latin America & Caribbean           High income  Not classified
# 3621       Europe & Central Asia  Lower middle income             IDA
# 2196       Europe & Central Asia          High income  Not classified
# 2039       Europe & Central Asia  Lower middle income             IDA
# 1234         Sub-Saharan Africa            Low income             IDA
# 381          Sub-Saharan Africa   Lower middle income             IDA
# 4108         Sub-Saharan Africa   Lower middle income           Blend

# %%
df["Year"].unique()
# Out:
# array([2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022])

# %%
df_filtered = df[df["Year"] == 2010].dropna(subset=["Population, total", "GDP per capita (current US$)", "Region"])
print(df_filtered.shape)
df_filtered.sample(5)
# Out:
# (209, 9)
#       Year              Country  GDP per capita (current US$)  \
# 3521  2010                Sudan                   1706.414917
# 1279  2010              Finland                  46505.303179
# 1260  2010                 Fiji                   3469.149643
# 3730  2010  Trinidad and Tobago                  15711.558706
# 4091  2010               Zambia                   1469.361450
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 3521                                63.016000         33739933.0          SDN
# 1279                                79.870732          5363352.0          FIN
# 1260                                67.328000           905169.0          FJI
# 3730                                72.725000          1410296.0          TTO
# 4091                                56.799000         13792086.0          ZMB
#
#                           Region         Income Group    Lending Type
# 3521         Sub-Saharan Africa            Low income             IDA
# 1279       Europe & Central Asia          High income  Not classified
# 1260         East Asia & Pacific  Upper middle income           Blend
# 3730  Latin America & Caribbean           High income            IBRD
# 4091         Sub-Saharan Africa   Lower middle income             IDA

# %%
population_by_region = df_filtered.groupby("Region")["Population, total"].sum().reset_index()

population_by_region
# Out:
#                        Region  Population, total
# 0         East Asia & Pacific       2.162379e+09
# 1       Europe & Central Asia       8.889814e+08
# 2  Latin America & Caribbean        5.886271e+08
# 3  Middle East & North Africa       3.979976e+08
# 4               North America       3.433972e+08
# 5                  South Asia       1.660546e+09
# 6         Sub-Saharan Africa        8.677708e+08

# %%
fig = px.pie(
    population_by_region,
    values='Population, total',
    names='Region',
    title=f"Total Population Distribution by Region in {year_of_interest}",
    labels={'Population, total': 'Total Population'},
    hole=0.3
)
# Update traces to show both number and percentage
fig.update_traces(textinfo='label+value+percent')
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c012192d-a55e-4975-b6dd-f2f0a3650f54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c012192d-a55e-4975-b6dd-f2f0a3650f54")) {                    Plotly.newPlot(                        "c012192d-a55e-4975-b6dd-f2f0a3650f54",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"Region=%{label}\u003cbr\u003eTotal Population=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["East Asia & Pacific","Europe & Central Asia","Latin America & Caribbean ","Middle East & North Africa","North America","South Asia","Sub-Saharan Africa "],"legendgroup":"","name":"","showlegend":true,"values":[2162378942.0,888981434.0,588627089.0,397997557.0,343397156.0,1660546144.0,867770770.0],"type":"pie","textinfo":"label+value+percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{ ...

# %% [markdown]
# ## Exercise
#
# Calculate average GDP per capita for  each region and make a bar chart.

# %%
gdp_by_region = df_filtered.groupby('Region').agg(
    {
        'GDP per capita (current US$)': 'mean'
    }
).reset_index()

gdp_by_region
# Out:
#                        Region  GDP per capita (current US$)
# 0         East Asia & Pacific                  14068.845158
# 1       Europe & Central Asia                  31303.467052
# 2  Latin America & Caribbean                   12172.214861
# 3  Middle East & North Africa                  15578.718956
# 4               North America                  66029.336876
# 5                  South Asia                   2059.989661
# 6         Sub-Saharan Africa                    2310.375822

# %%
fig = px.bar(
    data_frame=gdp_by_region,
    x='Region',
    color="Region",
    y='GDP per capita (current US$)',
    title='Average GDP per Capita by Region',
    labels={
        'GDP per capita (current US$)': 'Average GDP per Capita (Current US$)',
        'Region': 'Region'
    },
    text='GDP per capita (current US$)'
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c9406aca-6e95-4cdc-923a-b9515d4d8fa0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9406aca-6e95-4cdc-923a-b9515d4d8fa0")) {                    Plotly.newPlot(                        "c9406aca-6e95-4cdc-923a-b9515d4d8fa0",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"East Asia & Pacific","offsetgroup":"East Asia & Pacific","orientation":"v","showlegend":true,"text":[14068.84515827713],"textposition":"auto","x":["East Asia & Pacific"],"xaxis":"x","y":[14068.84515827713],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Europe & Central Asia","offsetgroup":"Europe & Central Asia","orientation":"v","showlegend":true,"text":[31303.467051661613],"textposition":"auto","x":["Europe & Central Asia"],"xaxis":"x","y":[31303.467051661613],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean ","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Latin America & Caribbean ","offsetgroup":"Latin America & Caribbean ","orientation":"v","showlegend":true,"text":[12172.214860564287],"textposition":"auto","x":["Latin America & Caribbean "],"xaxis":"x","y":[12172.214860564287],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Middle East & North Africa","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Middle East & North Africa","offsetgroup":"Middle East & North Africa","orientation":"v","showlegend":true,"text":[15578.718955551416],"textposition":"auto","x":["Middle East & North Africa"],"xaxis":"x","y":[15578.718955551416],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"text":[66029.33687569977],"textposition":"auto","x":["North America"],"xaxis":"x","y":[66029.33687569977],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South Asia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South Asia","offsetgroup":"South Asia","orientation":"v","showlegend":true,"text":[2059.9896610305664],"textposition":"auto","x":["South Asia"],"xaxis":"x","y":[2059.9896610305664],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sub-Saharan Africa ","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Sub-Saharan Africa ","offsetgroup":"Sub-Saharan Africa ","orientation":"v","showlegend":true,"text":[2310.3758224682306],"textposition":"auto","x":["Sub-Saharan Africa "],"xaxis":"x","y":[2310.3758224682306],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogra ...

# %% [markdown]
# ## 10/09/2024 Homework Question 2
#
# Round the Average GDP for each region to 2 decimal points.
# Sort the bar according to GDP either in ascending order. Currently, it is ordered alphabetically.

# %%
gdp_by_region = df_filtered.groupby('Region').agg(
    {
        'GDP per capita (current US$)': 'mean'
    }
).reset_index()

gdp_by_region
# Out:
#                        Region  GDP per capita (current US$)
# 0         East Asia & Pacific                  14068.845158
# 1       Europe & Central Asia                  31303.467052
# 2  Latin America & Caribbean                   12172.214861
# 3  Middle East & North Africa                  15578.718956
# 4               North America                  66029.336876
# 5                  South Asia                   2059.989661
# 6         Sub-Saharan Africa                    2310.375822

# %%
gdp_by_region['GDP per capita (current US$)'] = gdp_by_region['GDP per capita (current US$)'].round(2)
gdp_by_region_sorted = gdp_by_region.sort_values(by='GDP per capita (current US$)', ascending=True)

gdp_by_region_sorted
# Out:
#                        Region  GDP per capita (current US$)
# 5                  South Asia                       2059.99
# 6         Sub-Saharan Africa                        2310.38
# 2  Latin America & Caribbean                       12172.21
# 0         East Asia & Pacific                      14068.85
# 3  Middle East & North Africa                      15578.72
# 1       Europe & Central Asia                      31303.47
# 4               North America                      66029.34

# %% [markdown]
# ## Home work question 4
#
# 1. remove the color legend.
# 2. Order the above bar chart based on the values of the average GDP per capita.

# %%
# Short cut to comment out many lines of code:
# First hightlight the code block
# then, hold down CTL, then press +/


# data = {
#     'Gender': ['Male', 'Female', 'Male', 'Female', 'Male'],
#     'Grade': ['A', 'B', 'A', 'A', 'B'],
#     'Score': [90, 85, 92, 88, 78]
# }

# df = pd.DataFrame(data)

# # Define the aggregate functions to be applied to the 'Score' column
# agg_functions = {
#     'Score': ['mean', 'max']
# }

# # Group by 'Gender' and 'Grade', then apply the aggregate functions
# grouped = df.groupby(['Gender', 'Grade']).aggregate(agg_functions)

# print(grouped)

# %%
df_2018 = df[df["Year"] == 2018]
print(df_2018.shape)
df_2018.sample(5)
# Out:
# (217, 9)
#       Year             Country  GDP per capita (current US$)  \
# 299   2018          Bangladesh                   1963.412492
# 2142  2018             Liberia                    700.037039
# 3073  2018  Russian Federation                  11287.354492
# 185   2018               Aruba                  30918.483584
# 3833  2018              Tuvalu                   4419.259998
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 299                                 72.567000        163683958.0          BGD
# 2142                                60.853000          4889391.0          LBR
# 3073                                72.662195        144477859.0          RUS
# 185                                 76.072000           105962.0          ABW
# 3833                                64.212000            10865.0          TUV
#
#                           Region         Income Group    Lending Type
# 299                   South Asia  Lower middle income             IDA
# 2142         Sub-Saharan Africa            Low income             IDA
# 3073       Europe & Central Asia  Upper middle income            IBRD
# 185   Latin America & Caribbean           High income  Not classified
# 3833         East Asia & Pacific  Upper middle income             IDA

# %%
def q1(x):
    return x.quantile(0.25)

def q3(x):
    return x.quantile(0.75)



df_group = df_2018.groupby("Region").aggregate(
    {
     'Life expectancy at birth, total (years)': ['min', 'mean', q1, "median", q3, 'max'],
     'GDP per capita (current US$)': ['min', 'mean', q1, "median", q3, 'max']
    }
)

df_group
# Out:
#                            Life expectancy at birth, total (years)             \
#                                                                min       mean
# Region
# East Asia & Pacific                                      63.234000  73.848374
# Europe & Central Asia                                    68.796000  78.131777
# Latin America & Caribbean                                64.019000  74.797838
# Middle East & North Africa                               63.038000  75.545677
# North America                                            78.639024  80.435976
# South Asia                                               63.081000  71.088625
# Sub-Saharan Africa                                       52.554000  62.542100
#
#                                                                       \
#                                    q1   median         q3        max
# Region
# East Asia & Pacific         68.461500  72.1625  79.667823  84.934146
# Europe & Central Asia       75.013707  78.6960  81.760976  83.753659
# Latin America & Caribbean   73.127500  74.4680  77.073750  80.614000
# Middle East & North Africa  72.794000  76.0660  79.722000  82.802439
# North America               79.732012  80.8250  81.334451  81.843902
# South Asia                  68.354750  70.9195  73.362250  80.013000
# Sub-Saharan Africa          60.020750  62.3980  65.414500  75.733000
#
#                            GDP per capita (current US$)                \
#                                                     min          mean
# Region
# East Asia & Pacific                         1241.164485  18083.532845
# Europe & Central Asia                        850.666958  36165.933995
# Latin America & Caribbean                   1489.578406  15005.516403
# Middle East & North Africa                   701.714868  16439.887429
# North America                              46548.638411  74140.894910
# South Asia                                   492.090632   3249.655429
# Sub-Saharan Africa                           232.060617   2497.289753
#
#                                                                       \
#                                       q1        median            q3
# Region
# East Asia & Pacific          3249.086977   6598.976695  31792.165412
# Europe & Central Asia        7252.403668  23165.849479  51466.556563
# Latin America & Caribbean    6282.155427   9574.310271  18648.651035
# Middle East & North Africa   3562.330943   5601.467061  25415.846625
# North America               54685.973925  62823.309438  87937.023160
# South Asia                   1505.940531   1968.895112   3632.479161
# Sub-Saharan Africa            729.773250   1178.708534   2288.949504
#
#
#                                       max
# Region
# East Asia & Pacific          84779.453694
# Europe & Central Asia       193968.090133
# Latin America & Caribbean    85231.774254
# Middle East & North Africa   66264.081168
# North America               113050.736882
# South Asia                   11034.723597
# Sub-Saharan Africa           16411.921117

# %%
df_group.to_excel("by_region.xlsx")

# %%
df_group.to_csv("by_region.csv")

# %%
# df_group.rename(columns={"min":"Minimum","max":"Maximum"}, inplace=True)  Alternative

COLUMN_DICT = {
    "min":"Minimum",
    "max":"Maximum",
    "mean": "Average",
    "q1": "1st Quartile",
    "q3": "3rd quartile"
}

df_group = df_group.rename(columns=COLUMN_DICT)
df_group
# Out:
#                            Life expectancy at birth, total (years)             \
#                                                            Minimum    Average
# Region
# East Asia & Pacific                                      63.234000  73.848374
# Europe & Central Asia                                    68.796000  78.131777
# Latin America & Caribbean                                64.019000  74.797838
# Middle East & North Africa                               63.038000  75.545677
# North America                                            78.639024  80.435976
# South Asia                                               63.081000  71.088625
# Sub-Saharan Africa                                       52.554000  62.542100
#
#                                                                           \
#                            1st Quartile   median 3rd quartile    Maximum
# Region
# East Asia & Pacific           68.461500  72.1625    79.667823  84.934146
# Europe & Central Asia         75.013707  78.6960    81.760976  83.753659
# Latin America & Caribbean     73.127500  74.4680    77.073750  80.614000
# Middle East & North Africa    72.794000  76.0660    79.722000  82.802439
# North America                 79.732012  80.8250    81.334451  81.843902
# South Asia                    68.354750  70.9195    73.362250  80.013000
# Sub-Saharan Africa            60.020750  62.3980    65.414500  75.733000
#
#                            GDP per capita (current US$)                \
#                                                 Minimum       Average
# Region
# East Asia & Pacific                         1241.164485  18083.532845
# Europe & Central Asia                        850.666958  36165.933995
# Latin America & Caribbean                   1489.578406  15005.516403
# Middle East & North Africa                   701.714868  16439.887429
# North America                              46548.638411  74140.894910
# South Asia                                   492.090632   3249.655429
# Sub-Saharan Africa                           232.060617   2497.289753
#
#                                                                       \
#                             1st Quartile        median  3rd quartile
# Region
# East Asia & Pacific          3249.086977   6598.976695  31792.165412
# Europe & Central Asia        7252.403668  23165.849479  51466.556563
# Latin America & Caribbean    6282.155427   9574.310271  18648.651035
# Middle East & North Africa   3562.330943   5601.467061  25415.846625
# North America               54685.973925  62823.309438  87937.023160
# South Asia                   1505.940531   1968.895112   3632.479161
# Sub-Saharan Africa            729.773250   1178.708534   2288.949504
#
#
#                                   Maximum
# Region
# East Asia & Pacific          84779.453694
# Europe & Central Asia       193968.090133
# Latin America & Caribbean    85231.774254
# Middle East & North Africa   66264.081168
# North America               113050.736882
# South Asia                   11034.723597
# Sub-Saharan Africa           16411.921117

# %%
def q1(x):
    return x.quantile(0.25)

def q3(x):
    return x.quantile(0.75)



df_group = df_2018.groupby("Region").aggregate(
    Minimum=('Life expectancy at birth, total (years)', 'min'),
    Average=('Life expectancy at birth, total (years)', 'mean'),
    percentile_25=('Life expectancy at birth, total (years)', q1)
)

df_group
# Out:
#                               Minimum    Average  percentile_25
# Region
# East Asia & Pacific         63.234000  73.848374      68.461500
# Europe & Central Asia       68.796000  78.131777      75.013707
# Latin America & Caribbean   64.019000  74.797838      73.127500
# Middle East & North Africa  63.038000  75.545677      72.794000
# North America               78.639024  80.435976      79.732012
# South Asia                  63.081000  71.088625      68.354750
# Sub-Saharan Africa          52.554000  62.542100      60.020750

# %% [markdown]
# ## 10/09/2024 Homework question 3
#
# Group the dataset by Region and Income Group, calculate the average, min, and max of GDP per Capita & life Expentancy, total, average, min, and max of population, then save the result to Excel.

# %%
def q1(x):
    return x.quantile(0.25)

def q3(x):
    return x.quantile(0.75)



df_group = df_2018.groupby(["Region","Income Group"]).aggregate(
    {
     'Life expectancy at birth, total (years)': ['min', 'mean', q1, 'median', q3, 'max'],
     'GDP per capita (current US$)': ['min', 'mean', q1, 'median', q3, 'max'],
     'Population, total': ['min', 'mean', 'max']
    }
)

df_group
# Out:
#                                                Life expectancy at birth, total (years)  \
#                                                                                    min
# Region                     Income Group
# East Asia & Pacific        High income                                       63.234000
#                            Low income                                        73.031000
#                            Lower middle income                               65.182000
#                            Upper middle income                               64.212000
# Europe & Central Asia      High income                                       71.886585
#                            Lower middle income                               70.353000
#                            Upper middle income                               68.796000
# Latin America & Caribbean  High income                                       68.896000
#                            Lower middle income                               64.019000
#                            Not classified                                    71.979000
#                            Upper middle income                               71.793000
# Middle East & North Africa High income                                       77.212000
#                            Low income                                        64.575000
#                            Lower middle income                               63.038000
#                            Upper middle income                               71.514000
# North America              High income                                       78.639024
# South Asia                 Low income                                        63.081000
#                            Lower middle income                               66.482000
#                            Upper middle income                               80.013000
# Sub-Saharan Africa         High income                                       72.841463
#                            Low income                                        52.825000
#                            Lower middle income                               52.554000
#                            Upper middle income                               61.191000
#
#                                                                       \
#                                                      mean         q1
# Region                     Income Group
# East Asia & Pacific        High income          80.218726  79.362073
#                            Low income           73.031000  73.031000
#                            Lower middle income  69.653846  67.634000
#                            Upper middle income  71.211125  66.982500
# Europe & Central Asia      High income          80.441210  78.636585
#                            Lower middle income  71.121171  70.950000
#                            Upper middle income  74.832544  73.052500
# Latin America & Caribbean  High income          76.408532  74.799750
#                            Lower middle income  69.607750  66.815750
#                            Not classified       71.979000  71.979000
#                            Upper middle income  74.682474  73.294500
# Middle East & North Africa High income          80.066652  79.211750
#                            Low income           67.360000  65.967500
#                            Lower middle income  74.013125  73.331250
#                            Upper middle income  73.033667  72.154000
# North America              High income          80.435976  79.732012
# South Asia                 Low income           63.081000  63.081000
#                            Lower middle income  70.935833  69.411750
#                            Upper middle income  80.013000  80.013000
# Sub-Saharan Africa         High income          72.841463  72.841463
#                            Low income           61.076136  59.832500
#                            Lower middle income  62.626789  59.775500
#                            Upper middle income  65.932557  63.295000
#
#                                                                       \
#                                                    median         q3
# Region                     Income Group
# East Asia & Pacific        High income          82.687805  83.525915
#                            Low income           73.031000  73.031000
#                            Lower middle income  70.173000  71.318000
#                            Upper middle income  70.558500  76.169000
# Europe & Central Asia      High income          81.382000  82.426829
#                            Lower middle income  71.274500  71.445671
#                            Upper middle income  75.013707  76.904348
# Latin America & Caribbean  High income          76.755000  78.763128
#                            Lower middle income  70.281000  73.073000
#                            Not classified       71.979000  71.979000
#                            Upper middle income  74.015000  76.378500
# Middle East & North Africa High income          79.789500  81.285695
#                            Low income           67.360000  68.752500
#                            Lower middle income  75.862000  76.098250
#                            Upper middle income  72.794000  73.793500
# North America              High income          80.825000  81.334451
# South Asia                 Low income           63.081000  63.081000
#                            Lower middle income  70.919500  72.207500
#                            Upper middle income  80.013000  80.013000
# Sub-Saharan Africa         High income          72.841463  72.841463
#                            Low income           60.689500  63.217000
#                            Lower middle income  62.342000  64.716000
#                            Upper middle income  65.548000  66.148000
#
#                                                            \
#                                                       max
# Region                     Income Group
# East Asia & Pacific        High income          84.934146
#                            Low income           73.031000
#                            Lower middle income  73.976000
#                            Upper middle income  78.662000
# Europe & Central Asia      High income          83.753659
#                            Lower middle income  71.582683
#                            Upper middle income  79.184000
# Latin America & Caribbean  High income          80.614000
#                            Lower middle income  73.850000
#                            Not classified       71.979000
#                            Upper middle income  79.484000
# Middle East & North Africa High income          82.802439
#                            Low income           70.145000
#                            Lower middle income  79.729000
#                            Upper middle income  74.793000
# North America              High income          81.843902
# South Asia                 Low income           63.081000
#                            Lower middle income  75.748000
#                            Upper middle income  80.013000
# Sub-Saharan Africa         High income          72.841463
#                            Low income           67.067000
#                            Lower middle income  75.733000
#                            Upper middle income  74.416341
#
#                                                GDP per capita (current US$)  \
#                                                                         min
# Region                     Income Group
# East Asia & Pacific        High income                         10985.874397
#                            Low income                                   NaN
#                            Lower middle income                  1241.164485
#                            Upper middle income                  3902.661676
# Europe & Central Asia      High income                         12494.423579
#                            Lower middle income                   850.666958
#                            Upper middle income                  4156.957500
# Latin America & Caribbean  High income                          6094.909837
#                            Lower middle income                  1489.578406
#                            Not classified                               NaN
#                            Upper middle income                  4145.862351
# Middle East & North Africa High income                         19887.574311
#                            Low income                            701.714868
#                            Lower middle income                  2531.200079
#                            Upper middle income                  3562.330943
# North America              High income                         46548.638411
# South Asia                 Low income                            492.090632
#                            Lower middle income                  1161.534350
#                            Upper middle income                 11034.723597
# Sub-Saharan Africa         High income                         16411.921117
#                            Low income                            232.060617
#                            Lower middle income                   944.417269
#                            Upper middle income                  5687.381043
#
#                                                                             \
#                                                         mean            q1
# Region                     Income Group
# East Asia & Pacific        High income          39154.294420  27207.191287
#                            Low income                    NaN           NaN
#                            Lower middle income   2674.956798   1607.229825
#                            Upper middle income   7563.624684   4649.613301
# Europe & Central Asia      High income          52580.598845  23424.480460
#                            Lower middle income   1714.906971   1193.771579
#                            Upper middle income   6819.778284   4735.356340
# Latin America & Caribbean  High income          26563.676272  17682.398674
#                            Lower middle income   2350.032441   1858.788377
#                            Not classified                NaN           NaN
#                            Upper middle income   7936.641559   6282.155427
# Middle East & North Africa High income          36083.783990  25105.780797
#                            Low income             906.793480    804.254174
#                            Lower middle income   4218.960053   3308.464029
#                            Upper middle income   7000.698904   4581.899002
# North America              High income          74140.894910  54685.973925
# South Asia                 Low income             492.090632    492.090632
#                            Lower middle income   2411.738200   1706.410067
#                            Upper middle income  11034.723597  11034.723597
# Sub-Saharan Africa         High income          16411.921117  16411.921117
#                            Low income             644.254729    532.781959
#                            Lower middle income   1990.412441   1479.713477
#                            Upper middle income   7960.079428   6977.794422
#
#                                                                             \
#                                                       median            q3
# Region                     Income Group
# East Asia & Pacific        High income          36198.960923  47212.396840
#                            Low income                    NaN           NaN
#                            Lower middle income   2584.327802   3267.225069
#                            Upper middle income   6073.394579   9905.406383
# Europe & Central Asia      High income          47544.981147  62316.219949
#                            Lower middle income   1456.199214   1977.334606
#                            Upper middle income   6234.396136   8999.695168
# Latin America & Caribbean  High income          20826.503271  31059.857398
#                            Lower middle income   2219.772205   2711.016269
#                            Not classified                NaN           NaN
#                            Upper middle income   7833.195013   9347.665633
# Middle East & North Africa High income          31899.036178  43485.701249
#                            Low income             906.793480   1009.332786
#                            Lower middle income   3713.963297   4152.753080
#                            Upper middle income   5601.467061   8719.882884
# North America              High income          62823.309438  87937.023160
# South Asia                 Low income             492.090632    492.090632
#                            Lower middle income   1968.895112   3035.927410
#                            Upper middle income  11034.723597  11034.723597
# Sub-Saharan Africa         High income          16411.921117  16411.921117
#                            Low income             691.680836    772.202548
#                            Lower middle income   1815.605495   2282.358673
#                            Upper middle income   7381.315108   8463.116665
#
#                                                                \
#                                                           max
# Region                     Income Group
# East Asia & Pacific        High income           84779.453694
#                            Low income                     NaN
#                            Lower middle income    4189.052191
#                            Upper middle income   16152.389233
# Europe & Central Asia      High income          193968.090133
#                            Lower middle income    3096.562500
#                            Upper middle income   11287.354492
# Latin America & Caribbean  High income           85231.774254
#                            Lower middle income    3471.006951
#                            Not classified                 NaN
#                            Upper middle income   12383.149952
# Middle East & North Africa High income           66264.081168
#                            Low income             1111.872092
#                            Lower middle income    9225.845155
#                            Upper middle income   11838.298707
# North America              High income          113050.736882
# South Asia                 Low income              492.090632
#                            Lower middle income    4360.584735
#                            Upper middle income   11034.723597
# Sub-Saharan Africa         High income           16411.921117
#                            Low income              873.554887
#                            Lower middle income    4021.445556
#                            Upper middle income   11643.460596
#
#                                                Population, total  \
#                                                              min
# Region                     Income Group
# East Asia & Pacific        High income                   11924.0
#                            Low income                 25638149.0
#                            Lower middle income          110929.0
#                            Upper middle income           10865.0
# Europe & Central Asia      High income                   32648.0
#                            Lower middle income         6322800.0
#                            Upper middle income          622227.0
# Latin America & Caribbean  High income                   30335.0
#                            Lower middle income         6572233.0
#                            Not classified             29825653.0
#                            Upper middle income           70823.0
# Middle East & North Africa High income                  484630.0
#                            Low income                 19333463.0
#                            Lower middle income         1057198.0
#                            Upper middle income         4569087.0
# North America              High income                   63918.0
# South Asia                 Low income                 36686784.0
#                            Lower middle income          762096.0
#                            Upper middle income          489758.0
# Sub-Saharan Africa         High income                   96762.0
#                            Low income                  1924955.0
#                            Lower middle income          211344.0
#                            Upper middle income         1265577.0
#
#
#                                                         mean           max
# Region                     Income Group
# East Asia & Pacific        High income          1.594890e+07  1.268110e+08
#                            Low income           2.563815e+07  2.563815e+07
#                            Lower middle income  2.264876e+07  1.085688e+08
#                            Upper middle income  1.971614e+08  1.402760e+09
# Europe & Central Asia      High income          1.370278e+07  8.290578e+07
#                            Lower middle income  2.325739e+07  4.462252e+07
#                            Upper middle income  1.897782e+07  1.444779e+08
# Latin America & Caribbean  High income          1.843448e+06  1.870145e+07
#                            Lower middle income  9.746102e+06  1.160690e+07
#                            Not classified       2.982565e+07  2.982565e+07
#                            Upper middle income  2.829664e+07  2.101666e+08
# Middle East & North Africa High income          8.337268e+06  3.501813e+07
#                            Low income           2.506199e+07  3.079051e+07
#                            Lower middle income  3.707672e+07  1.037408e+08
#                            Upper middle income  1.721253e+07  4.059070e+07
# North America              High income          1.213224e+08  3.268382e+08
# South Asia                 Low income           3.668678e+07  3.668678e+07
#                            Lower middle income  3.005596e+08  1.369003e+09
#                            Upper middle income  4.897580e+05  4.897580e+05
# Sub-Saharan Africa         High income          9.676200e+04  9.676200e+04
#                            Low income           2.356441e+07  1.111294e+08
#                            Lower middle income  2.667020e+07  1.983876e+08
#                            Upper middle income  1.119273e+07  5.733964e+07

# %%
df_group.to_excel("by_region_incomegroup.xlsx")
